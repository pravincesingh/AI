# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\HP\\Desktop\\Python\\AI\\DataSet\\Sample5 - Brest Cancer.csv")
df.head(20)
# Out:
#     Clump Thickness  Cell Size  Cell Shape  Marginal Adhesion  \
# 0                 5          4           3                  1
# 1                 9          1           2                  6
# 2                10          4           7                  2
# 3                 6         10          10                 10
# 4                 1          1           1                  1
# 5                 7          6          10                  5
# 6                 8         10          10                  8
# 7                 8          4           4                  1
# 8                 5          8           8                 10
# 9                 4          1           1                  1
# 10                3          1           1                  1
# 11                1          2           2                  1
# 12                3          1           1                  1
# 13                5          3           2                  8
# ...

# %%
x=df['Clump Thickness'].values
y=df['Cell Size'].values
plt.scatter(x,y)
plt.show()
