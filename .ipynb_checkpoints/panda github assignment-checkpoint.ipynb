# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\HP\\Desktop\\Python\\AI\\DataSet\\earthquakes.csv")
df.head()
# Out:
#                       time   latitude  longitude  depth   mag magType  nst  \
# 0  2014-01-31 23:53:37.000  60.252000  -152.7081  90.20  1.10      ml  NaN
# 1  2014-01-31 23:48:35.452  37.070300  -115.1309   0.00  1.33      ml  4.0
# 2  2014-01-31 23:47:24.000  64.671700  -149.2528   7.10  1.30      ml  NaN
# 3  2014-01-31 23:30:54.000  63.188700  -148.9575  96.50  0.80      ml  NaN
# 4  2014-01-31 23:30:52.210  32.616833  -115.6925  10.59  1.34      ml  6.0
#
#       gap     dmin     rms net          id                   updated  \
# 0     NaN      NaN  0.2900  ak  ak11155107  2014-02-05T19:34:41.515Z
# 1  171.43  0.34200  0.0247  nn  nn00436847  2014-02-01T01:35:09.000Z
# 2     NaN      NaN  1.0000  ak  ak11151142  2014-02-01T00:03:53.010Z
# 3     NaN      NaN  1.0700  ak  ak11151135  2014-01-31T23:41:25.007Z
# 4  285.00  0.04321  0.2000  ci  ci37171541  2014-02-01T00:13:20.107Z
#
#                                place        type
# 0  26km S of Redoubt Volcano, Alaska  earthquake
# ...

# %%
df.rename(columns={'time':'dates'})
df.set_index('id')
# Out:
#                                time   latitude   longitude    depth   mag  \
# id
# ak11155107  2014-01-31 23:53:37.000  60.252000 -152.708100   90.200  1.10
# nn00436847  2014-01-31 23:48:35.452  37.070300 -115.130900    0.000  1.33
# ak11151142  2014-01-31 23:47:24.000  64.671700 -149.252800    7.100  1.30
# ak11151135  2014-01-31 23:30:54.000  63.188700 -148.957500   96.500  0.80
# ci37171541  2014-01-31 23:30:52.210  32.616833 -115.692500   10.590  1.34
# ci11419722  2014-01-31 23:30:36.930  32.567667 -117.013500    0.010  1.51
# ci11419714  2014-01-31 23:28:04.020  33.359000 -116.360500   12.980  1.17
# ak11151127  2014-01-31 23:22:52.000  62.800200 -150.696500   86.400  1.50
# ak11151125  2014-01-31 23:20:42.000  58.169500 -151.992400   50.100  2.10
# nc72153361  2014-01-31 23:17:34.300  37.686000 -121.728700    4.200  1.60
# usc000mqlp  2014-01-31 23:08:03.660  -4.975800  153.946600  110.180  4.20
# ak11155101  2014-01-31 23:01:26.000  60.385200 -147.650500   13.100  1.10
# ...

# %%
df.describe()
# Out:
#             latitude      longitude          depth            mag  \
# count  120108.000000  120108.000000  120107.000000  120065.000000
# mean       38.399579     -99.961402      28.375029       1.793958
# std        21.938258      82.996858      62.215416       1.343466
# min       -73.462000    -179.998900      -9.900000      -0.970000
# 25%        34.228917    -147.742025       4.100000       0.820000
# 50%        38.805300    -120.832000       9.200000       1.400000
# 75%        53.889500    -116.068100      22.880000       2.400000
# max        86.651400     179.998000     697.360000       8.200000
#
#                 nst           gap          dmin            rms
# count  59688.000000  94935.000000  85682.000000  119716.000000
# mean      17.878284    124.048978      0.893198       0.358174
# std       14.911369     68.518595      2.903966       0.364046
# min        0.000000      9.000000      0.000000       0.000000
# ...

# %%
df.sort_values(by='mag',ascending=False).head(20)
# Out:
#                            time  latitude  longitude   depth  mag magType  \
# 37371   2014-04-01 23:46:47.260  -19.6097   -70.7691   25.00  8.2     mww
# 50562   2014-06-23 20:53:09.700   51.8486   178.7352  109.00  7.9     mww
# 36918   2014-04-03 02:43:13.110  -20.5709   -70.4931   22.40  7.7     mww
# 33808   2014-04-12 20:14:39.300  -11.2701   162.1481   22.56  7.6     mww
# 31496   2014-04-19 13:28:00.810   -6.7547   155.0241   43.37  7.5     mww
# 33537   2014-04-13 12:36:19.230  -11.4633   162.0511   39.00  7.4     mww
# 95913   2014-10-14 03:51:34.460   12.5262   -88.1225   40.00  7.3     mww
# 31850   2014-04-18 14:27:24.920   17.3970  -100.9723   24.00  7.2     mww
# 34318   2014-04-11 07:07:23.130   -6.5858   155.0485   60.53  7.1     mww
# 106285  2014-11-15 02:31:41.720    1.8929   126.5217   45.00  7.1     mww
# 111052  2014-11-01 18:57:22.380  -19.6903  -177.7587  434.00  7.1     mww
# 97602   2014-10-09 02:14:31.440  -32.1082  -110.8112   16.54  7.0     mww
# ...

# %%
df.place
# Out:
# 0                     26km S of Redoubt Volcano, Alaska
# 1                               32km S of Alamo, Nevada
# 2                      12km NNW of North Nenana, Alaska
# 3                            22km S of Cantwell, Alaska
# 4                          10km WNW of Progreso, Mexico
# 5                              3km N of Tijuana, Mexico
# 6                 11km N of Borrego Springs, California
# 7                         61km NNW of Talkeetna, Alaska
# 8                            48km NNE of Kodiak, Alaska
# 9                        3km E of Livermore, California
# 10                 115km ESE of Taron, Papua New Guinea
# 11                          71km SE of Whittier, Alaska
# 12                     0km N of The Geysers, California
# 13                 4km WSW of Mammoth Lakes, California
# 14                 120km N of Raoul Island, New Zealand
# 15                        6km SSW of Lilbourn, Missouri
# 16                            South of the Fiji Islands
# ...

# %%
a=df['place'].str.rsplit(',', expand=True, n=1)
b=["Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"]
a=set(a[1])
b=set(b)
l=[]
for i in a:
    if i not in b:
        l.append(i)
# print(l)

l=list(l)
# print(df2)
newdf=df.assign(country=l)
print(newdf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-136a82da990c> in <module>()
#      19 # print(df2)
#      20
# ---> 21 newdf=df.assign(country=l)
#      22 print(newdf)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in assign(self, **kwargs)
#    3305         if PY36:
#    3306             for k, v in kwargs.items():
# -> 3307                 data[k] = com._apply_if_callable(v, data)
#    3308         else:
#    3309             # <= 3.5: do all calculations first...
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3114         else:
#    3115             # set column
# -> 3116             self._set_item(key, value)
#    3117
#    3118     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3189
# ...

# %%
a=[6,4,9,0,8]
b=[3,4,5,6]
l=[]
for i in a:
    if i not in b:
        l.append(i)
print(l)
# Out:
# [9, 0, 8]

# %% [markdown]
# ipl data set
# mathches
# cbond for plotting
